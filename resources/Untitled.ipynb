# %%
import pandas as pd
from sklearn.cluster import KMeans

# %%
sp = pd.read_excel('dataset.xlsx')
sp = sp[sp['Period'] == 'Night']
sp = sp.dropna()
sp
# Out:
#       Day  Month  Year    Road Day of Week      Hour Period       City  \
# 2      29      4  2020  Street   Wednesday  22:30:00  Night  São Paulo
# 4      27      4  2020  Street    Thursday  19:30:00  Night  São Paulo
# 6      26      4  2020  Street      Sunday  23:35:00  Night  São Paulo
# 7      26      4  2020  Street    Saturday  21:56:00  Night  São Paulo
# 12     20      4  2020  Street    Thursday  20:30:00  Night  São Paulo
# ...   ...    ...   ...     ...         ...       ...    ...        ...
# 2313    7      1  2017  Street    Saturday  23:30:00  Night  São Paulo
# 2315    6      1  2017  Street      Friday  19:45:00  Night  São Paulo
# 2316    6      1  2017  Street      Friday  22:40:00  Night  São Paulo
# 2317    6      1  2017  Street      Friday  18:00:00  Night  São Paulo
# 2318    5      1  2017  Street    Thursday  23:42:00  Night  São Paulo
#
#        Latitude  Longitude     Vehicle      Victim      Type Sex  Age
# ...

# %%
kmeans = KMeans(2)
#sp['cluster'] = kmeans.predict(sp[['Latitude', 'Longitude']])
#sp
x = sp[['Latitude', 'Longitude']]
kmeans.predict(x)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-15-5d1bd83d7e04> in <module>
#       3 #sp
#       4 x = sp[['Latitude', 'Longitude']]
# ----> 5 kmeans.predict(x)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in predict(self, X, sample_weight)
#    1197             Index of the cluster each sample belongs to.
#    1198         """
# -> 1199         check_is_fitted(self)
#    1200
#    1201         X = self._check_test_data(X)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
# ...
